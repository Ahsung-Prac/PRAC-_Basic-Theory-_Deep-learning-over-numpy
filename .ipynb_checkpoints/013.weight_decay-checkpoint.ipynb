# %%
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# %%
#가중치를 감소를 사용한다.
# 가중치 마다 각각의 손술함수에 weight에 비례한 값을 더한다
# 즉 오차역전파법에도 비례한 값이 더해지고, 가중치의 변화율이 감수한다.

# 결과 그래프를 보면, 가중치의 값이 커지는 것을 방지하여, 오버피팅을 방지한다.
# 하지만 weight의 변화도 작아지고, 값이 작게 유지되므로, testcase에 대해서도 100퍼센트의 정확도를 내지 못하고 있다.
# 그래도 범용성있는 결과를 보여준다.

# 오버피팅이란, 학습 case에만 딱맞춰 잘맞추게 되고, 다른 시험케이스에는 적용이 잘 안된다.

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1 # 가중치 감소를 사용할 경우!
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.10333333333333333, test acc:0.1033
# epoch:1, train acc:0.12, test acc:0.1123
# epoch:2, train acc:0.12666666666666668, test acc:0.1157
# epoch:3, train acc:0.14666666666666667, test acc:0.1245
# epoch:4, train acc:0.17, test acc:0.1394
# epoch:5, train acc:0.20666666666666667, test acc:0.1536
# epoch:6, train acc:0.25, test acc:0.1755
# epoch:7, train acc:0.3, test acc:0.1999
# epoch:8, train acc:0.31333333333333335, test acc:0.2174
# epoch:9, train acc:0.33, test acc:0.2342
# epoch:10, train acc:0.36, test acc:0.2507
# epoch:11, train acc:0.36333333333333334, test acc:0.2671
# epoch:12, train acc:0.38333333333333336, test acc:0.2794
# epoch:13, train acc:0.4166666666666667, test acc:0.301
# epoch:14, train acc:0.44, test acc:0.3173
# epoch:15, train acc:0.44333333333333336, test acc:0.3366
# epoch:16, train acc:0.44666666666666666, test acc:0.3444
# epoch:17, train acc:0.45666666666666667, test acc:0.3606
# ...

# %%
# 가중치 감소를 사용할 경우 정확도 자체는 조금 떨어졌지만,
# train data의 accuracy와 test의 차이가 줄어들었다. overfitting을 억제했다.

# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
